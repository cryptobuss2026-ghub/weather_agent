# %%
import os
import asyncio

import requests
from autogen_agentchat.agents import AssistantAgent 
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import OpenAIChatCompletionClient

os.environ["OPENAI_API_KEY"]= "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"
OPENWEATHER_API_KEY = "59ffc1a3ada4c24e287ec22458c7ab73"

model_client = OpenAIChatCompletionClient(
    model="gpt-4o-mini"
    )

async def get_weather(city:str)->str:
    try:
        url = "https://api.openweathermap.org/data/2.5/weather",
        params = {
            "q": city,
            "appid": OPENWEATHER_API_KEY,
            "units": "metric"
        }
        response = requests.get(url, params=params)
        data = requests.json()
        if response.status_code != 200 or "Weather" not in data:
            return f"Could not fetch Weather for the CITY :{city}"
        desc = data["weather"][0]["description"].capatalize()
        temp = data["main"]["temp"]
        locaion = data["name"]
        return f"{loction}: {desc}, {temp}"
    except Exception as e:
        return f"Could not fetching the weather {str(e)}"

agent = AssistantAgent(
     name = "weather_agnet",
     model_client= model_client,
     tools= [get_weather],
     system_message=(
          "You are a very helpful AI Weather Assistant. If the user ask abut the weather"
          "use the 'get_weather' tool to find realtime weather information"
     ),
     reflect_on_tool_use=True,
     model_client_stream=True
    )
async def main():
        await Console(agent.run_stream(task="What is the weather in Karachi"))
        await model_client.close()
await main()
# Out:
# ---------- TextMessage (user) ----------
# What is the weather in Karachi
# c:\Users\Famiy User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\autogen_ext\models\openai\_openai_client.py:466: UserWarning: Missing required field 'structured_output' in ModelInfo. This field will be required in a future version of AutoGen.
#   validate_model_info(self._model_info)
# ---------------------------------------------------------------------------
# APIStatusError                            Traceback (most recent call last)
# Cell In[7], line 61
#      57     )
#      58 async def main():
#      59         await Console(agent.run_stream(task="What is the weather in Karachi"))
#      60         await model_client.close()
# ---> 61 await main()
#
# Cell In[7], line 59, in main()
#      58 async def main():
# ---> 59         await Console(agent.run_stream(task="What is the weather in Karachi"))
#      60         await model_client.close()
#
# ...
